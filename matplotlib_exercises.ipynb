# %% [markdown]
# #### 1. Use matplotlib to plot the following equation: y = x**2 - x + 2. You'll need to write the code that generates the x and y points. Add an anotation for the point 0, 0, the origin.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate data for x values
x = pd.Series(range(0, 10, 1))

# write function to get y values
def squared_minus_x_plus_two(x):
    return x ** 2 - x + 2
y = x.apply(squared_minus_x_plus_two)
y.head()
# this seems to be a long way to do things when we could just leverage vectorized operation of pandas since our x values are a pandas series
# Out:
# 0     2
# 1     2
# 2     4
# 3     8
# 4    14
# dtype: int64

# %%
# do the same using a lambda to generate data for y values
y = (lambda x: x**2 - x + 2)(x)
y.head()
# shorter, but still not necessary
# Out:
# 0     2
# 1     2
# 2     4
# 3     8
# 4    14
# dtype: int64

# %%
y = x.apply(lambda x: x**2 - x + 2)
y.head()
# Out:
# 0     2
# 1     2
# 2     4
# 3     8
# 4    14
# dtype: int64

# %%
# can't we just do this simply by leveraging vectorized operations in pandas?
y = x**2 - x + 2
y.head()
# same result, shorter and more straightforward
# Out:
# 0     2
# 1     2
# 2     4
# 3     8
# 4    14
# dtype: int64

# %%
plt.plot(x, y, c = 'green')
plt.annotate('Origin', xy=(0, 0), xytext=(0, 10),
             arrowprops={'facecolor': 'red'})
plt.show()

# %% [markdown]
# #### 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense): You can use functions from the math module to help implement some of the equations above.
# ![image.png](attachment:8ec2492b-cdc8-4cb0-8ad3-c004e3945a40.png)

# %%
x = pd.Series(range(0, 10, 1))

y = x ** 0.5

plt.plot(x, y)
plt.title(r'$y=\sqrt{x}$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
y.head()
# Out:
# 0    0.000000
# 1    1.000000
# 2    1.414214
# 3    1.732051
# 4    2.000000
# dtype: float64

# %%
# we could also do it like this, but doesn't seem necessary to go through extra steps

def sqrt(x):
    return x ** 0.5

y = x.apply(sqrt)

y.head()
# Out:
# 0    0.000000
# 1    1.000000
# 2    1.414214
# 3    1.732051
# 4    2.000000
# dtype: float64

# %%
x = pd.Series(range(0, 10, 1))

y = x ** 3

plt.plot(x, y)
plt.title('$y = x^3$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
x = pd.Series(range(0, 10, 1))

y = 2 ** x

plt.plot(x, y)
plt.title('$y=2^x$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %%
x = pd.Series(range(0, 10, 1))

y = 1 / (x + 1)

plt.plot(x, y)
plt.title(r'y = $\frac{1}{x+1}$')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.show()

# %% [markdown]
# #### 3. Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
n_rows = 2
n_cols = 2

plt.figure(figsize=(14, 10))

# x values
x = pd.Series(range(0, 10, 1))

# plot the first subplot
plt.subplot(n_rows, n_cols, 1)
y1 = x ** 0.5
plt.plot(x, y1)
plt.title(r'$y=\sqrt{x}$')
plt.xlabel('$x$')
plt.ylabel('$y$')

# the second subplot
plt.subplot(n_rows, n_cols, 2)
y2 = x ** 3
plt.plot(x, y2)
plt.title('$y = x^3$')
plt.xlabel('$x$')
plt.ylabel('$y$')

# the third subplot
plt.subplot(n_rows, n_cols, 3)
y3 = 2 ** x
plt.plot(x, y3)
plt.title('$y=2^x$')
plt.xlabel('$x$')
plt.ylabel('$y$')

# the fourth subplot
plt.subplot(n_rows, n_cols, 4)
y4 = 1 / (x + 1)
plt.plot(x, y4)
plt.title(r'y = $\frac{1}{x+1}$')
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.tight_layout()

plt.show()

# %% [markdown]
# #### 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
x = pd.Series(np.linspace(0, 2, 100))

y1 = x ** 0.5
plt.plot(x, y1, label=r'$y=\sqrt{x}$')

y2 = x ** 3
plt.plot(x, y2, label='$y = x^3$')

y3 = 2 ** x
plt.plot(x, y3, label='$y=2^x$')

y4 = 1 / (x + 1)
plt.plot(x, y4, label=r'y = $\frac{1}{x+1}$')

plt.title('Combined Plots')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.show()

# %%
x = pd.Series(np.linspace(0, 1, 100))
