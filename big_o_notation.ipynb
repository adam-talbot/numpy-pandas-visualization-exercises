# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](attachment:8fa35cd4-e7a3-438a-9a17-380ff41f26fb.png)

# %%
import math

plt.figure(figsize=(14, 10))

n = pd.Series(range(1, 5, 1))

y1 = 0*n + 1
plt.plot(n, y1, label='O(1)')

y2 = np.log(n)
plt.plot(n, y2, label='O(log n)')

y3 = n
plt.plot(n, y3, label='O(n)')

y4 = n * np.log(n)
plt.plot(n, y4, label='O(n log n)')

y5 = n ** 2
plt.plot(n, y5, label='O(n^2)')

y6 = 2 ** n
plt.plot(n, y6, label='O(2^n)')

y7 = n.apply(math.factorial) # couldnt get the math.factorial or my user create factorial to vectorize so had to use the apply() method for this one
plt.plot(n, y7, label='O(n!)')

y8 = n ** n
plt.plot(n, y8, label='O(n^n)')

plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.legend()

plt.show()

# %%
from scipy.special import factorial

plt.figure(figsize=(14, 10))

n = pd.Series(np.linspace(0.1, 2, 100))

y1 = 0*n + 1
plt.plot(n, y1, label='O(1)')

y2 = np.log(n)
plt.plot(n, y2, label='O(log n)')

y3 = n
plt.plot(n, y3, label='O(n)')

y4 = n * np.log(n)
plt.plot(n, y4, label='O(n log n)')

y5 = n ** 2
plt.plot(n, y5, label='O(n^2)')

y6 = 2 ** n
plt.plot(n, y6, label='O(2^n)')

y7 = factorial(n) # couldnt get the math.factorial or my user create factorial to vectorize so had to use the apply() method for this one
plt.plot(n, y7, label='O(n!)')

y8 = n ** n
plt.plot(n, y8, label='O(n^n)')

plt.title('Big O Notation')
plt.xlabel('Elements')
plt.ylabel('Operations')
plt.legend()

plt.show()

# %%
# write a function to find the factorial of a number
# factorial of 5 = 5 * 4 * 3 * 2 * 1

def factorial(n):
    for i in range(1 , n):
        n *= i
    return n

# %% [markdown]
# #### 6. Bonus Write the code necessary to write your name on a chart. Use box letters.

# %%
# not sure what box letter are

x = pd.Series(range(0,27))

# %%
plt.plot(x, color='black')
plt.text(4, 6, "Adam Talbot", color='green', size=27, style='oblique', weight='black', rotation=33)
# Out:
# Text(4, 6, 'Adam Talbot')
